# %%
import requests

url = "https://mariomagdy.pythonanywhere.com/initiate"
files = {'image': open('imgs\Annoteted_PoleImage_21.JPG', 'rb')}
data = {'base_coordinates': '100,200'}  # Example coordinates

response = requests.post(url, files=files, data=data)
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
# ...

# %%
import requests

url = "http://127.0.0.1:5000//initiate"
files = {'image': open('imgs\Annoteted_PoleImage_21.JPG', 'rb')}
data = {'base_coordinates': '100,200'}  # Example coordinates

response = requests.post(url, files=files, data=data)
print(response.json())
# Out:
# {'got_scale': False, 'image': '...'}

# %%
import requests

url = "http://127.0.0.1:5000//scale_using_reference"
# files = {'image': open('imgs\Annoteted_PoleImage_21.JPG', 'rb')}
data = {'reference_point': '1331,2546'}  # Example coordinates

response = requests.post(url, data=data)
print(response.json())
# Out:
# {'error': 'No image available from initiate call'}

# %%
from datetime import datetime

# datetime object containing current date and time
now = datetime.now()
 
print("now =", now)

# dd/mm/YY H:M:S
dt_string = now.strftime("%Y/%m/%d %H:%M:%S")
print("date and time =", dt_string)
# Out:
# now = 2024-08-15 22:49:49.977100
# date and time = 15/08/2024 22:49:49
